# %%
# Start writing code here...

import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
hfi_2020 = pd.read_csv("/work/Datasets/hfi_cc_2020.csv")
hfi_2019 = pd.read_csv("/work/Datasets/hfi_cc_2019.csv")
hfi_2018 = pd.read_csv("/work/Datasets/hfi_cc_2018.csv")

hci_male_2020 = pd.read_csv("/work/Datasets/hci_Male_september_2020.csv")
hci_female_2020 = pd.read_csv("/work/Datasets/hci_Female_september_2020.csv")
hci_malefemale_2020 = pd.read_csv("/work/Datasets/hci_MaleFemale_september_2020.csv")
hfi_2020
# Out:
#       Unnamed: 0  year ISO_code countries              region  hf_score  \
# 0              0  2018      ALB   Albania      Eastern Europe      7.81
# 1              1  2017      ALB   Albania      Eastern Europe      7.78
# 2              2  2016      ALB   Albania      Eastern Europe      7.63
# 3              3  2015      ALB   Albania      Eastern Europe      7.55
# 4              4  2014      ALB   Albania      Eastern Europe      7.65
# ...          ...   ...      ...       ...                 ...       ...
# 1777        1777  2012      ZWE  Zimbabwe  Sub-Saharan Africa      5.38
# 1778        1778  2011      ZWE  Zimbabwe  Sub-Saharan Africa      5.28
# 1779        1779  2010      ZWE  Zimbabwe  Sub-Saharan Africa      4.97
# 1780        1780  2009      ZWE  Zimbabwe  Sub-Saharan Africa      4.91
# 1781        1781  2008      ZWE  Zimbabwe  Sub-Saharan Africa      4.97
#
#       hf_rank  hf_quartile  pf_rol_procedural  pf_rol_civil  ...  \
# ...

# %%
plt.figure()
hfi_2020.plot(figsize=(10,10), legend=None)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=72b1e015-02d7-48b2-beb6-dcae4caaa79e' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
